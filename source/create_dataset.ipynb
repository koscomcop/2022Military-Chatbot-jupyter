# %% [markdown]
# # Environments

# %%
import pandas as pd
import numpy as np

# %%
WORK_DIR='E://Workspace/Git/2022Military-Chatbot-jupyter/'

# %% [markdown]
# ## Setting for colab

# %%
# Clone Git Repo(only for Google Colab)
# !git clone https://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@github.com/koscomcop/2022Military-Chatbot-jupyter.git

# %%
WORK_DIR='/content/2022Military-Chatbot-jupyter/'
# %cd $WORK_DIR
# Out:
# /content/2022Military-Chatbot-jupyter

# %% [markdown]
# #### Git Push

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git add .
# !git status

# %%
# Push Git Repo
# !git config --global user.email "dlruddla89@gmail.com"
# !git config --global user.name "katie0809"

# %%
# !git commit -m '복지 질문 학습셋 추가'

# %%
# !git remote add origin https://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@github.com/koscomcop/2022Military-Chatbot-jupyter.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push origin main
# Out:
# Counting objects: 4, done.
# Delta compression using up to 8 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 19.20 KiB | 3.84 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/koscomcop/2022Military-Chatbot-jupyter.git
#    6a51d53..c96f9bd  main -> main

# %% [markdown]
# # 일상대화 데이터셋 제작

# %%
FILES_DIR=WORK_DIR+'files/korean_qa/'

# %%
import os

korean_qas = []
for dirname, _, filenames in os.walk(FILES_DIR):
    for filename in filenames:
        filepath = os.path.join(dirname, filename)
        sample_df = pd.read_excel(filepath, encoding='utf-8')
        korean_qas.append(sample_df)
        print(f'[{filename.split(".")[0]}] # of data : {len(sample_df.index)} ======================================>')
        display(sample_df.head())
        print('\n')
# Out:
# [A 음식점(15,726)_new] # of data : 15726 ======================================>
#   SPEAKER                                           SENTENCE DOMAINID DOMAIN  \
# 0      고객                                          지금 배달되나요?        A    음식점
# 1      점원                                          아 네 배달됩니다        A    음식점
# 2      고객                       짬뽕류는 어떤 게 있나요? 잘 나가는 짬뽕 있나요?        A    음식점
# 3      점원  특해물 짬뽕도 있고 전복 새우 짬뽕도 있고 해물 종류도 새우 홍합 전복 없는 게 없습니다        A    음식점
# 4      고객                          전복 들어가는 거는 특해물 짬뽕 시켜야 돼요?        A    음식점
#
#   CATEGORY  SPEAKERID SENTENCEID         MAIN  SUB QA QACNCT  \
# 0    배달음식점          1          1       배달가능문의  NaN  Q    NaN
# 1    배달음식점          0          2       배달가능문의  NaN  A    NaN
# 2    배달음식점          1          3  베스트메뉴문의추천요청  NaN  Q    NaN
# 3    배달음식점          0          4  베스트메뉴문의추천요청  NaN  A    NaN
# 4    배달음식점          1          5       메뉴정보문의  NaN  Q    NaN
#
#                              MQ   SQ   UA  \
# ...

# %%
train_chat = pd.DataFrame(columns=['question', 'class', 'topic', 'entities', 'synonym'])
train_chat
# Out:
# Empty DataFrame
# Columns: [question, class, topic, entities, synonym]
# Index: []

# %%
for _qa in korean_qas[:9]:
    _qa = _qa[_qa['QA']=="Q"]
    _qa = _qa[['SENTENCE', 'DOMAIN', 'MAIN', '개체명', '지식베이스']]
    _qa.columns = train_chat.columns
    train_chat = pd.concat([train_chat, _qa], axis=0)
    
train_chat = train_chat.reset_index(drop=True)

# %%
train_chat
# Out:
#                                   question class        topic       entities  \
# 0                                지금 배달되나요?   음식점       배달가능문의     수고, 지금, 배달
# 1             짬뽕류는 어떤 게 있나요? 잘 나가는 짬뽕 있나요?   음식점  베스트메뉴문의추천요청             짬뽕
# 2                전복 들어가는 거는 특해물 짬뽕 시켜야 돼요?   음식점       메뉴정보문의     전복, 특해물 짬뽕
# 3               전복 들어가고 여러 가지 또 딴 것도 들어가죠?   음식점       메뉴정보문의             전복
# 4                     마차이 짬뽕밥은 돼지고기 들어가나요?   음식점       메뉴정보문의  마차이 짬뽕밥, 돼지고기
# ...                                    ...   ...          ...            ...
# 51060                1억 원대에 매매 가능한 토지 있어요?  부동산업    희망매매가매물문의            NaN
# 51061  평당 500만 원 정도로 매매 가능한 토지 있는지 알려주실래요?  부동산업    희망매매가매물문의            NaN
# 51062    2억 5000만 원까지 생각하고 있는데 그런 토지가 있나요?  부동산업    희망매매가매물문의            NaN
# 51063            지금 가장 싼 토지 매물 한 번 보여주실래요?  부동산업    희망매매가매물문의            NaN
# 51064                  평당 90만으로 괜찮은 곳 있어요?  부동산업    희망매매가매물문의            NaN
#
#                    synonym
# ...

# %%
train_chat['class'].unique()
# Out:
# array(['음식점', '의복의류점', '학원', '소매', '생활서비스', '카페', '숙박', '관광여가오락', '부동산',
#        '부동산업'], dtype=object)

# %%
train_chat.to_csv(WORK_DIR+'files/raw_chat.csv', index=False)

# %%
# 학습용으로 1만개만 뽑아서 따로 저장
import random

train_chat_small = train_chat[['question']].sample(5000)

# %%
train_chat_small.to_csv(WORK_DIR+"files/train_chat.csv", index=False)

# %% [markdown]
# # 의도 데이터셋 제작

# %%
FILES_DIR=WORK_DIR+'assets/'

# %%
import os

raw_datas = []
for dirname, _, filenames in os.walk(FILES_DIR):
    for filename in filenames:
        filepath = os.path.join(dirname, filename)
        print(filename)
# Out:
# 국방부 병사 보급기준 정보_20200924.csv
# 국방부_국군복지단 복지시설_20220426.csv
# 병사 봉급 정보.csv
# 제7296부대 병영 표준 식단.xls.pia
# 국방부_군 복지 휴양시설 정보_10_01_2018.csv
# 국방부_TMO(여행장병 안내소) 정보_20190930.csv
# 국방부_한국국방연구원 도서관 보유 국내외 정기간행물 목록_20210930.csv
# 방위사업청_국방통합 용어사전_20210915.csv
# 국방전자도서관 도서정보.csv
# 국방부_국군복지단 복지지설 상세 현황_20220426.csv
# 국방부_신분별 군 정원_20200101.csv
# 국방부_군인(간부) 봉급표_20200930.csv
# 국방부_병사 할인 혜택 정보_20220426.csv
# 국방부_영외 군인아파트 현황_20201231.csv
# 국방부_현역군인 내 집 마련 정보_20210816.csv
# 국방부_군 복지시설 주변 관광지 정보_20200831.csv
# 국방부_군인연금 기금운용 현황_20201231.csv
# 국방부_군인연금 기금자산 현황_20201231.csv
# 국방부_군병원 정보_20200701.csv
# 국방부 PX 인기상품 정보_20220531.csv
# 국방부_영외 군인아파트 현황_20201231.csv
# 국방부_공군사관학교 교육과정_20200930.csv
# 국방부_육군사관학교 교육과정_20210918.xlsx.pia
# 연도별 장병 체력검정 기준 정보.csv
# 국방부_육군3사관학교 교육과정_20200930.csv
# 국방부_해군사관학교 교육과정_20200930.csv
# 국방부_군인연금 수급인원 현황_20201231.csv
# 군사법원 연락처 정보.csv
# 국방부_육사신문_20200929.zip
# 국방부_체력단련장 정보_20190829..csv

# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv(FILES_DIR+'국방부_군인(간부) 봉급표_20200930.csv', encoding='utf-8')
df
# Out:
#     호봉         소장         준장         대령         중령         소령         대위  \
# 0    1  5346400.0  5043700.0  4094500.0  3599200.0  2965300.0  2411900.0
# 1    2  5478600.0  5174700.0  4232200.0  3736800.0  3099700.0  2538600.0
# 2    3  5610800.0  5305700.0  4369900.0  3874400.0  3234100.0  2665300.0
# 3    4  5743000.0  5436700.0  4507600.0  4012000.0  3368500.0  2792000.0
# 4    5  5875200.0  5567700.0  4645300.0  4149600.0  3502900.0  2918700.0
# 5    6  6007400.0  5698700.0  4783000.0  4287200.0  3637300.0  3045400.0
# 6    7  6139600.0  5829700.0  4920700.0  4424800.0  3771700.0  3172100.0
# 7    8  6271800.0  5960700.0  5058400.0  4562400.0  3906100.0  3298800.0
# 8    9  6404000.0  6091700.0  5196100.0  4700000.0  4040500.0  3425500.0
# 9   10  6536200.0  6222700.0  5333800.0  4837600.0  4174900.0  3552200.0
# 10  11  6668400.0  6353700.0  5471500.0  4975200.0  4309300.0  3678900.0
# 11  12  6800600.0  6484700.0  5609200.0  5112800.0  4443700.0  3805600.0
# ...

# %%
file_names = [
#     '국방부 PX 인기상품 정보_20220531.csv',
#     '국방부 병사 보급기준 정보_20200924.csv',
    '국방부_TMO(여행장병 안내소) 정보_20190930.csv',
    '국방부_국군복지단 복지시설_20220426.csv',
    '국방부_국군복지단 복지지설 상세 현황_20220426.csv',
    '국방부_군 복지 휴양시설 정보_10_01_2018.csv',
#     '국방부_군 복지시설 주변 관광지 정보_20200831.csv',
#     '국방부_군병원 정보_20200701.csv',
#     '국방부_군인(간부) 봉급표_20200930.csv',
    '국방부_병사 할인 혜택 정보_20220426.csv',
#     '국방부_신분별 군 정원_20200101.csv',
#     '방위사업청_국방통합 용어사전_20210915.csv',
]

# %%
def print_dfs(file_names):
    for fnm in file_names:
        sample_df=pd.read_csv(FILES_DIR+fnm, encoding='utf-8')
        print(f'[{fnm.split(".")[0]}] # of data : {len(sample_df.index)} ======================================>')
        display(sample_df.head())
        print('\n')

# %%
print_dfs(file_names)
# Out:
# [국방부_TMO(여행장병 안내소) 정보_20190930] # of data : 50 ======================================>
#    TMO명        일반전화번호 평일운용시간(시작) 평일운용시간(종료) 주말운용시간(시작) 주말운용시간(종료)  \
# 0    강릉  033-641-9690       7:00      18:00       7:00      18:00
# 1    경산  053-750-4556       7:20      17:10        NaN        NaN
# 2    계룡  042-550-4254       6:30      20:00       6:30      20:00
# 3    광명   02-801-6791       7:00      19:00       7:00      19:00
# 4  광주송정  062-940-7788       7:00      19:00       7:00      19:00
#
#                       위치설명     비고
# 0           3번출구2시방향여자화장실옆    NaN
# 1            경산역출구에서좌측4m지점  휴일미운용
# 2  계룡역역광장출구방향정면30m지점붉은벽돌건물    NaN
# 3            광명역서편1번출구지하1층    NaN
# 4                광주송정역1층운영    NaN
# [국방부_국군복지단 복지시설_20220426] # of data : 73 ======================================>
#     구분     시설명                        주소           연락처
# 0  기숙사  대방학사1관       서울시 영등포구여의대방로 49길 3   02-847-0981
# 1  기숙사  대방학사2관     서울시 영등포구여의대방로 43라길 17   02-832-2219
# ...

# %% [markdown]
# ## 의도 총 6개
# - 복지 : 할인혜택, 휴양시설, 복지시설
# - 주거 : 관사주택정보, 관사분양정보
# - 정원 : 군별 병사/장교 인원정보
# - 급여 : 병사/장교 급여정보
# - 도서
# - 식단
#
# ## 1.복지
# ### 1) QnA Template
# - 특정시설 정보 질몬
#     - 특정시설 일반정보 답변
# - 특정지역 시설여부 질문
#     - 특정지역 해당 시설목록 답변
#     - 특정지역 해당 여행장병안내소 답변
#
# ### 2) Named Entity
# : 추출해야할 개체 종류 ==> 지역, 시설

# %% [markdown]
# #### 개체추출 ==> 지역

# %%
def get_dfs(file_names):
    dfs = []
    for fnm in file_names:
        sample_df = pd.read_csv(FILES_DIR+fnm, encoding='utf-8')
        dfs.append(sample_df)
        print(f'[{fnm.split(".")[0]}] # of data : {len(sample_df.index)} ======================================>')
        display(sample_df.head())
        print('\n')
        
    return dfs

# %%
df_welfare = get_dfs(file_names)
# Out:
# [국방부_TMO(여행장병 안내소) 정보_20190930] # of data : 50 ======================================>
#    TMO명        일반전화번호 평일운용시간(시작) 평일운용시간(종료) 주말운용시간(시작) 주말운용시간(종료)  \
# 0    강릉  033-641-9690       7:00      18:00       7:00      18:00
# 1    경산  053-750-4556       7:20      17:10        NaN        NaN
# 2    계룡  042-550-4254       6:30      20:00       6:30      20:00
# 3    광명   02-801-6791       7:00      19:00       7:00      19:00
# 4  광주송정  062-940-7788       7:00      19:00       7:00      19:00
#
#                       위치설명     비고
# 0           3번출구2시방향여자화장실옆    NaN
# 1            경산역출구에서좌측4m지점  휴일미운용
# 2  계룡역역광장출구방향정면30m지점붉은벽돌건물    NaN
# 3            광명역서편1번출구지하1층    NaN
# 4                광주송정역1층운영    NaN
# [국방부_국군복지단 복지시설_20220426] # of data : 73 ======================================>
#     구분     시설명                        주소           연락처
# 0  기숙사  대방학사1관       서울시 영등포구여의대방로 49길 3   02-847-0981
# 1  기숙사  대방학사2관     서울시 영등포구여의대방로 43라길 17   02-832-2219
# ...

# %%
# 지역 카테고리 따로 있는경우
locales = list(df_welfare[0]['TMO명'].unique())
locales += list(df_welfare[2]['지역1'].unique())
locales += list(df_welfare[2]['지역2'].unique())
locales += list(df_welfare[4]['지역'].unique())
print(set(locales))
# Out:
# {'마산', '만종', '영동', '퇴계원', '창원중앙', '김천구미', '청량리', '강릉', '평택', '익산', '홍성', '제주', '인천', '신경주', '논산', '전국', '장성', '제천', '수원', '신탄진', '창원', '증평', '서울', '전라', '전남', '용산', '전주', '동대구', '계룡', '충북', '진주', '서울,강원', '오근장', '춘천', '경상', '진해', '영천', '지평', '충청', '포항', '구포', '부강', '경북', '천안아산', '대구', '울산', '대전', '경기', '광명', '강원', '충남', '경남', '원주', '광주송정', '동서울', '오송', '부평', '조치원', '연무대', '서대전', '수서', '덕정', '목포', '경산', '부산', '전북'}

# %%
# 주소정보에서 지역 추출 : df_welfare[1]
df_welfare1_locales = list(df_welfare[1]['주소'].apply(lambda x:x.split(' ')[0]).unique())
print(df_welfare1_locales)
locales += df_welfare1_locales
# Out:
# ['서울시', '경기도', '광주광역시', '대구시', '강원도', '서울특별시', '대전광역시', '부산광역시', '경기', '서울', '제주도', '경남', '전남', '충청남도', '충남', '충청북도', '전북', '제주특별자치도', '충북', '경북', '경상북도', '전라남도', '경상남도', '부산시']

# %%
# 주소정보에서 지역 추출 : df_welfare[3]
df_welfare3_locales = list(df_welfare[3]['위치 주소'].apply(lambda x:x.split(' ')[0]).unique())
print(df_welfare3_locales)
locales += df_welfare3_locales
# Out:
# ['제주도', '강원도', '충남', '대전시', '서울시', '제주', '경남', '부산시']

# %%
locales = list(set(locales))
print(locales)
# Out:
# ['마산', '영동', '청량리', '김천구미', '제주', '서울특별시', '전국', '제천', '경기도', '신탄진', '전주', '계룡', '충북', '진주', '서울,강원', '오근장', '춘천', '지평', '포항', '대구', '대전', '강원', '오송', '덕정', '목포', '만종', '충청남도', '인천', '수원', '충청북도', '창원', '증평', '전라남도', '진해', '구포', '부강', '광주송정', '동서울', '서울시', '서대전', '수서', '경산', '부산', '퇴계원', '대구시', '창원중앙', '익산', '논산', '서울', '용산', '대전시', '동대구', '충청', '경북', '천안아산', '경기', '광명', '경남', '원주', '강원도', '부산시', '연무대', '전라', '전북', '평택', '강릉', '홍성', '신경주', '장성', '전남', '대전광역시', '경상', '경상북도', '영천', '제주특별자치도', '부산광역시', '울산', '충남', '제주도', '광주광역시', '부평', '조치원', '경상남도']

# %% [markdown]
# #### 개체추출 : 시설

# %%
facilities = ['TMO', '여행장병 안내소', '여행장병안내소']

# %%
# 시설명 따로 있는경우
facilities += list(df_welfare[1]['시설명'].unique())
facilities += list(df_welfare[2]['시설명'].unique())
facilities += list(df_welfare[3]['시설 명'].unique())
facilities += list(df_welfare[4]['시설명'].unique())
facilities = list(set(facilities))
print(facilities)
# Out:
# ['국방컨벤션', '켄싱턴호텔 여의도/평창/설악 지점', '소노문 양평', '한화 제주', '네스트호텔', '소노 소노캄 여수', '에어부산(수송사)', '롯데렌터카', '롯데씨티호텔마포/구로/대전점', '대천콘도1관', '로젠이사', '금호 설악', '소노벨 경주', '태릉 체력단련장', '켄싱턴 설악 밸리', '한화 평창', '소노문 델피노', '라마다제주 시티호텔(제주)', '아바니센트럴호텔(부산)', '에버랜드 자유이용(국.복지정책과)', '금호 화순', '롯데시네마(국.복지정책과)', '청풍리조트(제천)', '라마다호텔(평창)', '풍림아이원호텔&리조트(평창)', '파라다이스호텔(부산)', '밀리토피아 골프연습장', '무열학사', '처인 체력단련장', '소노 소노문 델피노', '해운대 그린나래호텔', '여행장병안내소', '손조 소노벨 비발디파크', '인제스피디움', '그라벨제주호텔', '소노문 단양', '계룡스파텔', '세종호텔', '더프라자호텔 서울', '신세계(영랑호)', '제주다인오세아노호텔앤리조트', '디오션리조트호텔(여수)', '송파학사', '하이원리조트', '베스트웨스턴프리미어 서울가든호텔', '롯데호텔 울산', '여행장병 안내소', '바이라한포항', '쏠비치 삼척', '소양학사', '한화 해운대', '금호 통영', '켄싱턴 한림', '라마다플라자호텔(제주)', '코오롱 마우나오션리조트(경주)', '대구그랜드호텔', '한화 거제(벨버디어)', '자운학사', '켄싱턴 경주', '소노 소노문 양평', '빕스할인(국.복지정책과)', '쏠비치 양양', '대방학사2관', '씨마크 호텔', '남수원 체력단련장', '현대수 설악', '한화 산정호수(안시)', '코엑스아쿠아리움', '코리아나호텔', '호텔더숨포레스트', '소노캄 거제', '동여주 체력단련장', '리솜 아일랜드(안면도)', '청간정카라반', '소노벨 변산', '켄싱턴 해운대', '금호 제주', '포포츠버이쉐라톤강남호텔', '아스타호텔 제주', '용평리조트 스키시즌권', 'JDX 멀티스포
# ...

# %%
# 시설명에서 불용어, 특수기호 제거
stw_f = ['(국.복지정책과)', '(수송사)', '(민간위탁)']
for i, x in enumerate(facilities):
    for s in stw_f:
        facilities[i] = facilities[i].replace(s, '')
    loc_idx = facilities[i].find('(')
    if loc_idx > 0:
        facilities[i] = facilities[i][:loc_idx]
    
print(set(facilities))
# Out:
# {'국방컨벤션', '켄싱턴호텔 여의도/평창/설악 지점', '소노문 양평', '한화 제주', '네스트호텔', '소노 소노캄 여수', '로젠이사', '롯데렌터카', '롯데씨티호텔마포/구로/대전점', '대천콘도1관', '금호 설악', '소노벨 경주', '태릉 체력단련장', '켄싱턴 설악 밸리', '한화 평창', '소노문 델피노', '더 플래닛', '한화 경주', '금호 화순', '밀리토피아 골프연습장', '무열학사', '처인 체력단련장', '소노 소노문 델피노', '해운대 그린나래호텔', '여행장병안내소', '손조 소노벨 비발디파크', '인제스피디움', '그라벨제주호텔', '노보텔앰배서더 수원', '소노문 단양', '계룡스파텔', '세종호텔', '더프라자호텔 서울', '제주다인오세아노호텔앤리조트', '송파학사', '하이원리조트', '베스트웨스턴프리미어 서울가든호텔', '롯데호텔 울산', '여행장병 안내소', '바이라한포항', '쏠비치 삼척', '소양학사', '한화 해운대', '제주항공', '금호 통영', '켄싱턴 한림', '파라다이스호텔', '대구그랜드호텔', '티웨이항공', '자운학사', '켄싱턴 경주', '소노 소노문 양평', '쏠비치 양양', '대방학사2관', '씨마크 호텔', '남수원 체력단련장', '현대수 설악', '코엑스아쿠아리움', '코리아나호텔', '호텔더숨포레스트', '소노캄 거제', '한화 용인', '동여주 체력단련장', '라마다플라자호텔', '청간정카라반', '라마다제주 시티호텔', '한화 산정호수', '풍림아이원호텔&리조트', '소노벨 변산', '켄싱턴 해운대', '코오롱호텔', '금호 제주', '포포츠버이쉐라톤강남호텔', '아스타호텔 제주', '펠릭스 바이 에스티엑스', '용평리조트 스키시즌권', 'JDX 멀티스포츠', '진해해군회관', '신세계', '거제삼성호텔 ', '씨에스호텔앤리조트', '바이라한 울산', '세인트포골프&리조트', '서귀포호텔', '국민트랜스', '용평리조트 피크아일랜드', '청간정콘도', '리솜 아일랜드', '대방학
# ...

# %%
q_welfare = []

# %%
w_welfare = {
    'LOCALE': locales,
    'FACILITIES': facilities,
    'A': ['근처', '주변', '부근', '근방', '쪽에',  '지역'],
    'B': ['있어?', '있긴해?', '있음?', '뭐가 있어?', '있을까?'],
    'C': ['시설', '복지시설', '놀만한 곳', '갈만한 곳', '할인되는 곳', '숙소', '잘데', '혜택', '복지정보'],
    'D': ['알려줘', '궁금해', '궁금함', '말해줘', '알고싶어']
}
t_welfare = [
    '{LOCALE}{A} {C} {B}',
    '{LOCALE}{A} {C} {D}',
    '{FACILITIES}에 대해 {D}',
    '{FACILITIES} 혜택정보 {D}'
]

# %%
len(facilities)
# Out:
# 188

# %%
import re

# return chunk key list
# get template pattern string
def get_key_from_template(str):
  ret = re.findall(r'\{.*?\}', str)
  return list(map(lambda x:x.replace('{', '').replace('}', ''), ret))
  # return ret

def add_samples(permute):
    samples = []
    for chunks in permute:
      cur_q = template
      for i in range(len(chunks)):
        # print(key, chunks[i], cur_q)
        key = '{'+keylist[i]+'}'
        cur_q = cur_q.replace(key, chunks[i])

      samples.append(cur_q)

    return samples

# %%
from itertools import product
import random

samples = []
for template in t_welfare:
  keylist = get_key_from_template(template)

  if len(keylist)==2:
    # Get all possible cases
    permute = list(product(w_welfare[keylist[0]],w_welfare[keylist[1]]))

  elif len(keylist)==4:
    # Get all possible cases
    permute = list(product(w_welfare[keylist[0]],w_welfare[keylist[1]],w_welfare[keylist[2]],w_welfare[keylist[3]]))

    # Random sampling
    permute = random.sample(permute, 1000)

  samples += add_samples(permute)

# %%
df_welfare = pd.DataFrame(samples, columns=['question'])
df_welfare
# Out:
#                   question
# 0            서대전주변 시설 있긴해?
# 1           오송쪽에 복지시설 있긴해?
# 2          울산부근 할인되는 곳 있어?
# 3         인천근처 복지시설 뭐가 있어?
# 4             신탄진근방 숙소 있어?
# ...                    ...
# 3875   노보텔앰배서더 수원 혜택정보 알려줘
# 3876   노보텔앰배서더 수원 혜택정보 궁금해
# 3877   노보텔앰배서더 수원 혜택정보 궁금함
# 3878   노보텔앰배서더 수원 혜택정보 말해줘
# 3879  노보텔앰배서더 수원 혜택정보 알고싶어
#
# [3880 rows x 1 columns]

# %%
df_welfare.to_csv('train_welfare.csv', index=False)

# %%
# Out:
# 0

# %% [markdown]
# ## 2.주거
# ### 1) QnA Template
# - 지역별 관사주택정보 질문
#     - 특정지역 해당 주택목록 답변
#     - 특정지역 해당 분양정보 목록 답변
# - 특정주택 정보질문
#     - 특정주택 일반정보 답변
# - 군구분별 지역별 주택정보 질문
#     - 군 구분별 해당 주택목록 답변
#
# ### 2) Named Entity
# : 추출해야할 개체 종류 ==> 지역, 주택, 군구분
